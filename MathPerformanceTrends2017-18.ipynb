# %%
import os
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\laksh\Desktop\UNCLEANED DOE DATA 2017-18\UNCLEANEDMathPerformanceTrends.csv", encoding='cp1252')
df.head(10)
# Out:
#    CountyCode CountyName  DistrictCode  DistrictName  SchoolCode  \
# 0           1   ATLANTIC            10  ABSECON CITY          50
# 1           1   ATLANTIC            10  ABSECON CITY          50
# 2           1   ATLANTIC            10  ABSECON CITY          50
# 3           1   ATLANTIC            10  ABSECON CITY          50
# 4           1   ATLANTIC            10  ABSECON CITY          50
# 5           1   ATLANTIC            10  ABSECON CITY          50
# 6           1   ATLANTIC            10  ABSECON CITY          50
# 7           1   ATLANTIC            10  ABSECON CITY          50
# 8           1   ATLANTIC            10  ABSECON CITY          50
# 9           1   ATLANTIC            10  ABSECON CITY          50
#
#        SchoolName     Year Grade_Subject Subject MetExcExpPerc
# 0  EMMA C ATTALES  2017-18       Grade 5    Math            31
# 1  EMMA C ATTALES  2017-18       Grade 5    Math            31
# ...

# %%
df.isnull().sum()
# Out:
# CountyCode       0
# CountyName       0
# DistrictCode     0
# DistrictName     0
# SchoolCode       0
# SchoolName       0
# Year             0
# Grade_Subject    0
# Subject          0
# MetExcExpPerc    0
# dtype: int64

# %%
df.dtypes
# Out:
# CountyCode        int64
# CountyName       object
# DistrictCode      int64
# DistrictName     object
# SchoolCode        int64
# SchoolName       object
# Year             object
# Grade_Subject    object
# Subject          object
# MetExcExpPerc    object
# dtype: object

# %%
df['MetExcExpPerc'].replace(['*'],9999999)
# Out:
# 0             31
# 1             31
# 2             29
# 3             29
# 4             49
# 5             49
# 6        9999999
# 7        9999999
# 8             79
# 9             79
# 10            79
# 11            53
# 12            53
# 13            58
# 14            58
# 15       9999999
# 16       9999999
# 17       9999999
# 18            18
# 19            18
# 20            18
# 21       9999999
# 22       9999999
# 23       9999999
# 24            34
# 25            34
# 26            27
# 27            27
# 28            44
# 29            44
#           ...
# 18648    9999999
# 18649    9999999
# 18650    9999999
# 18651    9999999
# 18652    9999999
# 18653    9999999
# 18654         30
# 18655         30
# 18656         24
# 18657         24
# 18658         11
# 18659         11
# 18660         18
# 18661         18
# 18662         16
# 18663         16
# 18664         12
# 18665         12
# 18666         62
# 18667         62
# 18668         38
# ...

# %%
df.MetExcExpPerc = df.MetExcExpPerc.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e29db7bafecb> in <module>
# ----> 1 df.MetExcExpPerc = df.MetExcExpPerc.astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
df.loc[df['MetExcExpPerc']=='*']
# Out:
#        CountyCode CountyName  DistrictCode  \
# 6               1   ATLANTIC            10
# 7               1   ATLANTIC            10
# 15              1   ATLANTIC           110
# 16              1   ATLANTIC           110
# 17              1   ATLANTIC           110
# 21              1   ATLANTIC           110
# 22              1   ATLANTIC           110
# 23              1   ATLANTIC           110
# 59              1   ATLANTIC           110
# 60              1   ATLANTIC           110
# 68              1   ATLANTIC           110
# 69              1   ATLANTIC           110
# 70              1   ATLANTIC           110
# 71              1   ATLANTIC           110
# 72              1   ATLANTIC           110
# 73              1   ATLANTIC           110
# 74              1   ATLANTIC           110
# 75              1   ATLANTIC           110
# 76              1   ATLANTIC           110
# 77              1   ATLANTIC           110
# 78              1   ATLANTIC           110
# ...

# %%
df = df.replace('*',9999999)

# %%
df.loc[df['MetExcExpPerc']=='*']
# Out:
# Empty DataFrame
# Columns: [CountyCode, CountyName, DistrictCode, DistrictName, SchoolCode, SchoolName, Year, Grade_Subject, Subject, MetExcExpPerc]
# Index: []

# %%
df.MetExcExpPerc = df.MetExcExpPerc.astype(float)

# %%
df.dtypes
# Out:
# CountyCode         int64
# CountyName        object
# DistrictCode       int64
# DistrictName      object
# SchoolCode         int64
# SchoolName        object
# Year              object
# Grade_Subject     object
# Subject           object
# MetExcExpPerc    float64
# dtype: object

# %%
df.to_csv('cleanedMathPerformanceTrends2017-18.csv')
